# %% [markdown]
# #Proceso KDD:

# %%
import pandas as pd
import numpy as np
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

#se requiere instalado el paquete PyStemmer de Snowball
#para hallar las raices de las pal. en espanol:
import Stemmer
_stemmer = Stemmer.Stemmer('english')    #variable global para la funcion tokenize
#experimentalmente tiene mejor Accuracy


##en caso se use nltk:
#from nltk.stem.porter import *
#_stemmer = PorterStemmer()

from sklearn.model_selection import train_test_split

# %%
#Inicio del programa:

#leemos el archivo de entrenamiento (y prueba)
msgs = pd.read_csv('dataset.csv', sep=',', index_col=False).fillna("")
msgs
# Out:
#                                                Message Topic
# 0    \r\n\r\nIn article <1993Apr15.103953.66252@cc....     E
# 1    \r\n\r\n\r\nYes, I know it's nowhere near Chri...     E
# 2    \r\nX-Newsreader: TIN [version 1.1 PL6]\r\n\r\...     E
# 3    \r\nX-Received: by usenet.pa.dec.com; id AA267...     E
# 4    \r\n\r\nIn article <sehari.733764410@vincent1....     E
# 5    \r\n\r\nmarrevola@rediris.es wrote:\r\n: In ar...     E
# 6    \r\n\r\n    Hello netters:)  Does anyone out t...     E
# 7    \r\nSender: johnh@macadam (John Haddy)\r\nDist...     E
# 8    \r\nSender: johnh@macadam (John Haddy)\r\nDist...     E
# 9    \r\n\r\nIn article <20756.2bd16dea@ecs.umass.e...     E
# 10   \r\n\r\nIn article <1993Apr14.133007.11055@Pri...     E
# 11   \r\n\r\nBrian Day (bday@lambda.msfc.nasa.gov) ...     E
# 12   \r\n\r\nIn article <1qk4hj$qos@vtserf.cc.vt.ed...     E
# 13   \r\n\r\n\r\nI need the specs on various eprom ...     E
# 14   \r\n\r\nTony Kidson (tony@morgan.demon.co.uk) ...     E
# 15   \r\n\r\nAllMichael CovingtonTelephone on hook/...     E
# 16   \r\n\r\nYou can get a *little* UV by putting a...     E
# 17   \r\n\r\nHi,\r\n\r\n\tBeing a Electronic Engine...     E
# 18   \r\n\r\nbutts@shocker.ee.twsu.edu (Ronald W. B...     E
# 19                                            \r\n\r\n     E
# 20   \r\nDistribution: world\r\nMessage-ID: <1prbb1...     E
# 21   \r\n\r\nGreat, the first advantage of cheap co...     E
# 22   \r\nX-Newsreader: TIN [version 1.1.4 PL6]\r\n\...     E
# 23   \r\nDistribution: world\r\nMessage-ID: <Yfnutu...     E
# 24   \r\n\r\nIn article <1993Apr16.105738.20864@hip...     E
# 25   \r\n\r\nI repair a lot of monitors here, and I...     E
# 26   \r\nSender: news@cs.yale.edu (Usenet News)\r\n...     E
# 27   \r\n\r\nIn article <C5qwv2.Bz0@zoo.toronto.edu...     E
# 28   \r\n\r\nacollins@uclink.berkeley.edu (Andy Col...     E
# 29   \r\n\r\nIn article <1993Apr20.173742.99726@ns1...     E
# ..                                                 ...   ...
# 758  \r\n\r\nL(>  levin@bbn.com (Joel B Levin) writ...     M
# 759  \r\n\r\nIn article <C5sy24.LF4@watson.ibm.com>...     M
# 760  \r\nSender: mossman@mania (Amy Mossman)\r\nDis...     M
# 761  \r\n\r\nIn article <1993Mar30.030105.26772@ome...     M
# 762  \r\n\r\nIn article <1993Apr19.205615.1013@unlv...     M
# 763  \r\nMessage-ID: <1qrsr6$d59@access.digex.net>\...     M
# 764  \r\n\r\nIn article <1q1tbnINNnfn@life.ai.mit.e...     M
# 765  \r\nDate: Fri, 23 Apr 1993 08:07:34 +0000\r\nM...     M
# 766  \r\n\r\nBrenda Bowden (brenda@bookhouse.Eng.Su...     M
# 767  \r\nMessage-ID: <1r3klt$3ld@hsdndev.harvard.ed...     M
# 768  \r\n\r\nDN> From: nyeda@cnsvax.uwec.edu (David...     M
# 769  \r\n\r\nHello,\r\n\r\nI am planning on attendi...     M
# 770  \r\n\r\nIn article <1qk6v3INNrm6@lynx.unm.edu>...     M
# 771                 \r\n\r\nBULLSHIT ! ! !\r\n\r\n\r\n     M
# 772  \r\n\r\nIn article <1993Mar29.204003.26952@tij...     M
# 773  \r\nMessage-ID: <1rkoep$6m7@network.ucsd.edu>\...     M
# 774  \r\n\r\nThen there are always osteopathy colle...     M
# 775  \r\nDistribution: world\r\nMessage-ID: <1rmn0c...     M
# 776  \r\n\r\n\r\nA friend of mine is having some sy...     M
# 777  \r\n\r\nI am a student from San Leandro High s...     M
# 778  \r\nMessage-ID: <1r0vjf$op7@hsdndev.harvard.ed...     M
# 779  \r\n\r\n\r\nIn article <1qk4qqINNgvs@im4u.cs.u...     M
# 780  \r\n\r\n\r\nHi:\r\n\r\nI went to the orthopedi...     M
# 781  \r\n\r\nIn article <1993Mar26.005148.7899@aio....     M
# 782  \r\n\r\n>>>Can men get yeast infections? Sprea...     M
# 783  \r\n\r\nIn article <10030@blue.cis.pitt.edu> k...     M
# 784  \r\nMessage-ID: <1rag61$1cb@hsdndev.harvard.ed...     M
# 785  \r\n\r\nIn article <BHATT.93Apr12161425@wesley...     M
# 786  \r\n\r\naldridge@netcom.com (Jacquelin Aldridg...     M
# 787  \r\nNntp-Posting-Host: aisun3.ai.uga.edu\r\n\r...     M
#
# [788 rows x 2 columns]

# %%
#seleccionamos los datos objetivo:

yy = msgs["Topic"]
XX = msgs["Message"]
yy, XX
# Out:
# (0      E
#  1      E
#  2      E
#  3      E
#  4      E
#  5      E
#  6      E
#  7      E
#  8      E
#  9      E
#  10     E
#  11     E
#  12     E
#  13     E
#  14     E
#  15     E
#  16     E
#  17     E
#  18     E
#  19     E
#  20     E
#  21     E
#  22     E
#  23     E
#  24     E
#  25     E
#  26     E
#  27     E
#  28     E
#  29     E
#        ..
#  758    M
#  759    M
#  760    M
#  761    M
#  762    M
#  763    M
#  764    M
#  765    M
#  766    M
#  767    M
#  768    M
#  769    M
#  770    M
#  771    M
#  772    M
#  773    M
#  774    M
#  775    M
#  776    M
#  777    M
#  778    M
#  779    M
#  780    M
#  781    M
#  782    M
#  783    M
#  784    M
#  785    M
#  786    M
#  787    M
#  Name: Topic, dtype: object,
#  0      \r\n\r\nIn article <1993Apr15.103953.66252@cc....
#  1      \r\n\r\n\r\nYes, I know it's nowhere near Chri...
#  2      \r\nX-Newsreader: TIN [version 1.1 PL6]\r\n\r\...
#  3      \r\nX-Received: by usenet.pa.dec.com; id AA267...
#  4      \r\n\r\nIn article <sehari.733764410@vincent1....
#  5      \r\n\r\nmarrevola@rediris.es wrote:\r\n: In ar...
#  6      \r\n\r\n    Hello netters:)  Does anyone out t...
#  7      \r\nSender: johnh@macadam (John Haddy)\r\nDist...
#  8      \r\nSender: johnh@macadam (John Haddy)\r\nDist...
#  9      \r\n\r\nIn article <20756.2bd16dea@ecs.umass.e...
#  10     \r\n\r\nIn article <1993Apr14.133007.11055@Pri...
#  11     \r\n\r\nBrian Day (bday@lambda.msfc.nasa.gov) ...
#  12     \r\n\r\nIn article <1qk4hj$qos@vtserf.cc.vt.ed...
#  13     \r\n\r\n\r\nI need the specs on various eprom ...
#  14     \r\n\r\nTony Kidson (tony@morgan.demon.co.uk) ...
#  15     \r\n\r\nAllMichael CovingtonTelephone on hook/...
#  16     \r\n\r\nYou can get a *little* UV by putting a...
#  17     \r\n\r\nHi,\r\n\r\n\tBeing a Electronic Engine...
#  18     \r\n\r\nbutts@shocker.ee.twsu.edu (Ronald W. B...
#  19                                              \r\n\r\n
#  20     \r\nDistribution: world\r\nMessage-ID: <1prbb1...
#  21     \r\n\r\nGreat, the first advantage of cheap co...
#  22     \r\nX-Newsreader: TIN [version 1.1.4 PL6]\r\n\...
#  23     \r\nDistribution: world\r\nMessage-ID: <Yfnutu...
#  24     \r\n\r\nIn article <1993Apr16.105738.20864@hip...
#  25     \r\n\r\nI repair a lot of monitors here, and I...
#  26     \r\nSender: news@cs.yale.edu (Usenet News)\r\n...
#  27     \r\n\r\nIn article <C5qwv2.Bz0@zoo.toronto.edu...
#  28     \r\n\r\nacollins@uclink.berkeley.edu (Andy Col...
#  29     \r\n\r\nIn article <1993Apr20.173742.99726@ns1...
#                               ...
#  758    \r\n\r\nL(>  levin@bbn.com (Joel B Levin) writ...
#  759    \r\n\r\nIn article <C5sy24.LF4@watson.ibm.com>...
#  760    \r\nSender: mossman@mania (Amy Mossman)\r\nDis...
#  761    \r\n\r\nIn article <1993Mar30.030105.26772@ome...
#  762    \r\n\r\nIn article <1993Apr19.205615.1013@unlv...
#  763    \r\nMessage-ID: <1qrsr6$d59@access.digex.net>\...
#  764    \r\n\r\nIn article <1q1tbnINNnfn@life.ai.mit.e...
#  765    \r\nDate: Fri, 23 Apr 1993 08:07:34 +0000\r\nM...
#  766    \r\n\r\nBrenda Bowden (brenda@bookhouse.Eng.Su...
#  767    \r\nMessage-ID: <1r3klt$3ld@hsdndev.harvard.ed...
#  768    \r\n\r\nDN> From: nyeda@cnsvax.uwec.edu (David...
#  769    \r\n\r\nHello,\r\n\r\nI am planning on attendi...
#  770    \r\n\r\nIn article <1qk6v3INNrm6@lynx.unm.edu>...
#  771                   \r\n\r\nBULLSHIT ! ! !\r\n\r\n\r\n
#  772    \r\n\r\nIn article <1993Mar29.204003.26952@tij...
#  773    \r\nMessage-ID: <1rkoep$6m7@network.ucsd.edu>\...
#  774    \r\n\r\nThen there are always osteopathy colle...
#  775    \r\nDistribution: world\r\nMessage-ID: <1rmn0c...
#  776    \r\n\r\n\r\nA friend of mine is having some sy...
#  777    \r\n\r\nI am a student from San Leandro High s...
#  778    \r\nMessage-ID: <1r0vjf$op7@hsdndev.harvard.ed...
#  779    \r\n\r\n\r\nIn article <1qk4qqINNgvs@im4u.cs.u...
#  780    \r\n\r\n\r\nHi:\r\n\r\nI went to the orthopedi...
#  781    \r\n\r\nIn article <1993Mar26.005148.7899@aio....
#  782    \r\n\r\n>>>Can men get yeast infections? Sprea...
#  783    \r\n\r\nIn article <10030@blue.cis.pitt.edu> k...
#  784    \r\nMessage-ID: <1rag61$1cb@hsdndev.harvard.ed...
#  785    \r\n\r\nIn article <BHATT.93Apr12161425@wesley...
#  786    \r\n\r\naldridge@netcom.com (Jacquelin Aldridg...
#  787    \r\nNntp-Posting-Host: aisun3.ai.uga.edu\r\n\r...
#  Name: Message, dtype: object)

# %%
#separamos datos de entrenamiento
test_prop = 0.2
X_train, X_test, y_train, y_test = train_test_split(XX, yy, test_size = test_prop,    \
                                                    random_state = 23)

# %%
###INICIO DEL ENTRENAMIENTO:
#preprocesamiento:

def quitar_puntuacion(text):
    return re.sub("[^\w\d'\s]+",'',text)
 

def simplif_tab(text):
    return re.sub("[\t]+"," ",text)

def stem_tokens(tokens, stemmer):
    stemmed = _stemmer.stemWords(tokens)
    #stemmed = [_stemmer.stem(token) for token in tokens] #para nltk
    return stemmed

def tokenize(text):
    tokens = text.split()
    stems = stem_tokens(tokens, _stemmer)
    return stems



def preprocesamiento(X_train):
    #list_msgs = [msg.decode('iso8859-15') for msg in X_train]
    #list_msgs = [msg.encode('UTF-8') for msg in list_msgs]
    token_dict = {} 

    for (i,msg) in enumerate(X_train):
        msg = msg.lower()
        msg = simplif_tab(msg) 
        msg_sin_punt = quitar_puntuacion(msg)
        
        token_dict[i] = msg_sin_punt
    return token_dict

token_dict = preprocesamiento(X_train)

# %%
#transformacion: (usando el tfidf de sklearn con el clasif. Multinomial Naive Bayes)
tfidf = TfidfVectorizer(tokenizer = tokenize)
tfs = tfidf.fit_transform(token_dict.values())

classifier = MultinomialNB(alpha=1.0)  #clasificador bayesiano
classifier.fit(tfs,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
###Evaluacion del clasificador con la data de prueba (usando accuracy):

#funciones a usar:
def accuracy(y_pred, y_test):
    correct = 0
    total = len(y_test)
    for i, c in enumerate(y_test):
        if(y_pred[i] == c):
            correct += 1
    return correct/float(total)*100

def decod_veredicto(ch_veredicto):
    if(ch_veredicto == 'E'):
        s = "Electr."
    elif(ch_veredicto == 'M'):
        s = "Med."
    else:
        s = ""
    return s

def imprAcc(y_pred, y_test):
    print "Accuracy del clasificador Bayesiano: %.2f%%" %accuracy(y_pred, y_test)
    return


def reporteAcc(token_dict, y_pred, y_test, tope = 10):
    imprAcc(y_pred, y_test)
    #print "Accuracy del clasificador Bayesiano: %.2f%%" %accuracy(y_pred, y_test)
    #print
    print "\tMENSAJE\t\t\t\t\t\tPREDICCION\t\tTEMA REAL"
    for i, t in enumerate(y_test.index):
        if(i == tope):
            break
        print "\t", token_dict[i][:30]+"...", "\t\t\t", decod_veredicto(y_pred[i]), \
              "\t\t", decod_veredicto(y_test[t])



token_test = preprocesamiento(X_test)
tfs_pred = tfidf.transform(X_test)
y_pred = classifier.predict(tfs_pred)
reporteAcc(token_test, y_pred, y_test, tope=10)
# Out:
# Accuracy del clasificador Bayesiano: 86.71%
# 	MENSAJE						PREDICCION		TEMA REAL
#
#
# dr willian horatio bates b... 			Med. 		Med.
#
#
# last week i asked for help... 			Electr. 		Electr.
#
#
# brenda bowden brendabookho... 			Electr. 		Med.
#
#
# in article westesc60xqf59r... 			Med. 		Med.
#
#
# crispecsvaxuncecsedu russ ... 			Electr. 		Electr.
#
#
#
#  i was kind of half watc... 			Electr. 		Med.
#
#
# in article 1rm2bnkpstransf... 			Electr. 		Med.
#
#
# the casio 7500 lectric dia... 			Electr. 		Electr.
#
# nntppostinghost goytcsclivac... 			Electr. 		Electr.
#
# messageid 1quci2inn506fmsrl7... 			Electr. 		Electr.

# %%
#En un archivo CSV se observa una mejor presentacion:

def reporteCsvAcc(nombArch, X_raw, y_pred, y_test):
    import csv
    imprAcc(y_pred, y_test)
    with open(nombArch, 'wb') as csvfile:
        fwriter = csv.writer(csvfile, delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
        fwriter.writerow(['Message','Prediction','Topic'])
        for i, t in enumerate(y_test.index):
            fwriter.writerow([X_raw[t],y_pred[i],y_test[t]])    

reporteCsvAcc("rep.csv",X_test, y_pred, y_test)            
            
    
panda_csv = pd.read_csv('rep.csv', sep=',', index_col=False).fillna("")
panda_csv
# Out:
# Accuracy del clasificador Bayesiano: 86.71%
#                                                Message Prediction Topic
# 0    \r\n\r\nDr. willian Horatio Bates born 1860 an...          M     M
# 1    \r\n\r\nLast week I asked for help in getting ...          E     E
# 2    \r\n\r\nBrenda Bowden (brenda@bookhouse.Eng.Su...          E     M
# 3    \r\n\r\nIn article <westesC60xqF.59r@netcom.co...          M     M
# 4    \r\n\r\ncrisp@ecsvax.uncecs.edu (Russ Crisp) w...          E     E
# 5    \r\n\r\n\r\n\tI was kind of half watching Stre...          E     M
# 6    \r\n\r\nIn article <1rm2bn$kps@transfer.stratu...          E     M
# 7    \r\n\r\nThe Casio 7500 lectric diary has a 3-w...          E     E
# 8    \r\nNntp-Posting-Host: goyt.csc.liv.ac.uk\r\n\...          E     E
# 9    \r\nMessage-ID: <1quci2INN506@fmsrl7.srl.ford....          E     E
# 10   \r\n\r\nIn article <1993Apr27.182155.23426@osw...          M     M
# 11   \r\n\r\nmcole@spock (COLE) writes:\r\n\r\n>I w...          E     E
# 12   \r\nDistribution: world\r\nMessage-ID: <1r2ach...          E     M
# 13   \r\n\r\n\r\nDear Netters\r\nI want to send EMG...          E     E
# 14   \r\n\r\nIn article <1993Apr5.044140.1@vaxc.ste...          E     M
# 15   \r\n\r\nIn article <1993Apr15.100452.16793@csx...          E     E
# 16   \r\n\r\nIn article <80412@cup.portal.com> Mark...          M     M
# 17   \r\nMessage-ID: <ltijudINNj0e@saltillo.cs.utex...          M     M
# 18   \r\n\r\nJohn Ackermann x 2966 (jra@law7.Dayton...          E     E
# 19   \r\n\r\n     I posted about a "pulse of (relax...          E     M
# 20   \r\n\r\n\r\nI bought this chip from Suncoast T...          E     E
# 21   \r\n\r\nIn article <1993Apr22.143929.26131@mid...          M     M
# 22   \r\nMessage-ID: <1qkf2hINN65c@rave.larc.nasa.g...          E     E
# 23                                            \r\n\r\n          E     E
# 24   \r\n\r\nI've got the same problem; I can't dig...          E     E
# 25   \r\nSender: news@ntuix.ntu.ac.sg (USENET News ...          E     E
# 26   \r\n\r\nIn article <uabdpo.dpo.uab.edu-2304931...          M     M
# 27   \r\n\r\nAfter I have produced a schematic with...          E     E
# 28   \r\n\r\nIn article <1993Apr14.172145.27458@ecs...          E     E
# 29   \r\n\r\nIn article <1quqlgINN83q@im4u.cs.utexa...          E     M
# ..                                                 ...        ...   ...
# 128  \r\n\r\nI keep finding these programmers in lo...          E     E
# 129  \r\nMessage-ID: <1qpgsiINN31p@diplodocus.cis.o...          E     E
# 130                                               \r\n          E     M
# 131  \r\n\r\nL(>  levin@bbn.com (Joel B Levin) writ...          E     M
# 132  \r\n\r\nAllThe Devil ReincarnateSWR meter for ...          E     E
# 133  \r\n\r\nIn article rind@enterprise.bih.harvard...          M     M
# 134  \r\n\r\nI've recently picked up some TIL311 di...          E     E
# 135  \r\n\r\n\r\nC >Hi:\r\nC >I have a 486DX2-66MHz...          E     E
# 136  \r\n\r\nHi,\r\n\r\nRight now I should do some ...          E     E
# 137  \r\n\r\nIn article <C5r60r.4ID@megatest.com>, ...          E     E
# 138  \r\n\r\nIn article <cantrell.735330560@sauron....          E     E
# 139  \r\n\r\n\r\n    I was wondering if anyone out ...          E     E
# 140  \r\n\r\nIn article <C52DsD.7pB@compsci.liverpo...          E     E
# 141  \r\n\r\ndonrm@sr.hp.com (Don Montgomery) write...          E     E
# 142  \r\nMessage-ID: <1993Apr19.161519.1@venus.iteb...          M     M
# 143  \r\n\r\nI hope this is the correct newsgroup f...          E     M
# 144  \r\n\r\nIn article <1993Apr20.183416.18744@dre...          E     E
# 145  \r\nSender: daemon@cs.utexas.edu\r\nMessage-ID...          E     E
# 146  \r\nDistribution: world\r\nMessage-ID: <YfkEr1...          E     E
# 147  \r\n\r\nWayne Alan Martin <wm1h+@andrew.cmu.ed...          E     E
# 148  \r\n\r\nIn article <myers.735287742@peach.cs.s...          M     M
# 149  \r\nDistribution: world\r\nMessage-ID: <6APR19...          E     E
# 150                 \r\n\r\nBULLSHIT ! ! !\r\n\r\n\r\n          E     M
# 151  \r\n\r\nolsen@vetmed.cvm.uiuc.edu (Aart_Olsen)...          E     E
# 152  \r\nMessage-ID: <1qquvm$ndt@gondor.sdsu.edu>\r...          E     E
# 153  \r\n\r\ncaadams@atlas.cs.upei.ca (Kenny Adams)...          E     E
# 154  \r\n\r\nDoes anyone know what processor the At...          E     E
# 155  \r\n\r\nIn article <1rgnn6$lli@fnnews.fnal.gov...          M     M
# 156  \r\n\r\n\r\nSomeone I know has recently been d...          M     M
# 157  \r\n\r\nDoes any one know if the 6551 is timin...          E     E
#
# [158 rows x 3 columns]
